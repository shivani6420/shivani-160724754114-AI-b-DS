# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani6420/shivani-160724754114-AI-b-DS/blob/main/InsertionSort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Insertion Sort
n = int(input("Enter number of elements: "))
arr = []
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))

print("Original Array:", arr)

for i in range(1, n):
    key = arr[i]
    j = i - 1
    while j >= 0 and arr[j] > key:
        arr[j + 1] = arr[j]
        j -= 1
    arr[j + 1] = key

print("Sorted Array:", arr)
# Out:
# Enter number of elements: 5
# Enter element 1: 1
# Enter element 2: 2
# Enter element 3: 3
# Enter element 4: 4
# Enter element 5: 5
# Original Array: [1, 2, 3, 4, 5]
# Sorted Array: [1, 2, 3, 4, 5]
