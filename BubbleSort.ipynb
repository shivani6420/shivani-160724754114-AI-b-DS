# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani6420/shivani-160724754114-AI-b-DS/blob/main/BubbleSort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Bubble Sort
n=int(input("Enter the number of elements:"))
arr=[]
for i in range(n):
  arr.append(int(input(f"Enter element {i+1}:")))
print(f"Original Array:{arr}")
for i in range(n-1):
  for j in range(n-i-1):
    if arr[j ]>arr[j+1]:
      arr[j],arr[j+1]=arr[j+1],arr[j]
print("\nSorted Array:\n")
print(arr)
# Out:
# Enter the number of elements:3
# Enter element 1:5
# Enter element 2:2
# Enter element 3:1
# Original Array:[5, 2, 1]
#
# Sorted Array:
#
# [1, 2, 5]
