# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani6420/shivani-160724754114-AI-b-DS/blob/main/DataFiltering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Data Filtering
import pandas as pd
data={
    "ID":[101,102,103,104,105],
    "Name":["Alice","Bob","Charlie","David","Eva"],
    "Age":[22,25,23,24,26],
    "Marks":[85,78,92,88,90]
}
df=pd.DataFrame(data)
print("Original Data:")
print(df)
print("\nFiltering data where Names are Alice or Charlie\n")
print(df[(df["Name"] == 'Alice') | (df["Name"] == 'Charlie')])
print("\nFiltering data where Marks is greater than 85\n")
print(df[df["Marks"]>85])
print("\nFiltering data where Age is less than 25\n")
print(df[df["Age"]<25])
