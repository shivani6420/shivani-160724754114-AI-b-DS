# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani6420/shivani-160724754114-AI-b-DS/blob/main/SortingTechniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#SELECTION SORT
n = int(input("Enter number of elements: "))
arr = []
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))
print("\nOriginal array:", arr)
for i in range(n - 1):
    min_index = i
    for j in range(i + 1, n):
        if arr[j] < arr[min_index]:
            min_index = j
    # swap AFTER finding the minimum
    arr[i], arr[min_index] = arr[min_index], arr[i]
print("Sorted array:", arr)
# Out:
# Enter number of elements: 3
# Enter element 1: 1
# Enter element 2: 2
# Enter element 3: 3
#
# Original array: [1, 2, 3]
# Sorted array: [1, 2, 3]

# %%
#BUBBLE SORT
n = int(input("Enter number of elements: "))
arr = []
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))
print("\nOriginal array:", arr)
for i in range(n-1):
  for j in range(n-1-i):
    if arr[j] > arr[j+1]:
      arr[j],arr[j+1]=arr[j+1],arr[j]
print("Sorted array:", arr)
# Out:
# Enter number of elements: 2
# Enter element 1: 1
# Enter element 2: 2
#
# Original array: [1, 2]
# Sorted array: [1, 2]

# %%
623
#Bubble Sort
n=int(input("Enter the number of elements:"))
arr=[]
for i in range(n):
  arr.append(int(input(f"Enter element {i+1}:")))
print(f"Original Array:{arr}")
for i in range(n-1):
  for j in range(n-i-1):
    if arr[j ]>arr[j+1]:
      arr[j],arr[j+1]=arr[j+1],arr[j]
print("\nSorted Array:\n")
print(arr)
# Out:
# Enter the number of elements:3
# Enter element 1:1
# Enter element 2:2
# Enter element 3:3
# Original Array:[1, 2, 3]
#
# Sorted Array:
#
# [1, 2, 3]
