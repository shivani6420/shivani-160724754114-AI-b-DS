# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani6420/shivani-160724754114-AI-b-DS/blob/main/LinearSearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Linear Search
n=int(input("Enter the number of elements:"))
arr=[]
for i in range(n):
  arr.append(int(input(f"Enter element {i+1}:")))
key=int(input("\nEnter key element to be found:"))
found=False
for i in range(n):
  if arr[i]==key:
    print(f"Element found at position {i+1}")
    found=True
if found==False:
  print("Element not found")
# Out:
# Enter the number of elements:5
# Enter element 1:1
# Enter element 2:4
# Enter element 3:8
# Enter element 4:6
# Enter element 5:3
#
# Enter key element to be found:8
# Element found at position 3
