# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani6420/shivani-160724754114-AI-b-DS/blob/main/BinarySearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Binary Search
n = int(input("Enter the number of elements: "))
arr = []
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))
arr.sort()
print("\nSorted list:", arr)
key = int(input("\nEnter key element to be found: "))
low = 0
high = n - 1
found = False
while low <= high:
    mid = (low + high) // 2
    if arr[mid] == key:
        print(f"Element found at position {mid + 1}")
        found = True
        break
    elif arr[mid] < key:
        low = mid + 1
    else:
        high = mid - 1
if not found:
    print("Element not found")
# Out:
# Enter the number of elements: 5
# Enter element 1: 9
# Enter element 2: 8
# Enter element 3: 7
# Enter element 4: 6
# Enter element 5: 5
#
# Sorted list: [5, 6, 7, 8, 9]
#
# Enter key element to be found: 6
# Element found at position 2
