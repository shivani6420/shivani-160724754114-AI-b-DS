# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani6420/shivani-160724754114-AI-b-DS/blob/main/Filtering%2CManipulation%2Cranking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df=pd.read_csv(url)
print("Dataset (first 10 rows):")
print(df.head(10))
filtered_data=df[df["species"]=="versicolor"]
print("\nFiltered Data (species = versicolor):")
print(filtered_data.head())
df["petal_ratio"]=df["petal_length"]/df["petal_width"]
df.rename(columns={"sepal_length":"sepal_len"},inplace=True)
print("\nData after Manipulation (first 10 rows):")
print(df.head(10))
df["sepal_len_rank"]=df["sepal_len"].rank(ascending=False)
print("\nData with Ranking (sepal_len_rank) (first 10 rows):")
print(df[["sepal_len","sepal_len_rank"]].head(10))
# Out:
# Dataset (first 10 rows):
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa
#
# Filtered Data (species = versicolor):
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# ...
